# %% [markdown]
# # JSON-style Schema Skeletons (3 Versions)
#
# This notebook includes three schema skeletons for the DMP pipeline.
#
# ## 1. RDA maDMP Schema
#
# This is the base standard schema for structured DMP metadata.
#
# ## 2. DMPTool Schema
#
# This schema follows the DMPTool integration structure.
#
#
# ## 3. DMPTool Narrative Extension
#
# This part focuses only on the DMPTool-specific narrative layer.
#
# - Includes `provenance`
# - Includes narrative title
# - Organizes content into sections, questions, and answers.
# - Useful for mapping funder templates and LLM-generated responses.

# %%
#Import libraries
import requests
import xml.etree.ElementTree as ET
import json
from jsonschema import validate

# %% [markdown]
# # 1. RDA DMP Common Standard for machine-actionable Data Management Plans

# %%
# Final corrected maDMP schema skeleton
RDA_DMP_schema_skeleton = {
    "$schema": "./JSON-schema/1.2/maDMP-schema-1.2.json",
    "dmp": {
        "dmp_id": {
            "identifier": "",
            "type": ""
        },
        "title": "",
        "description": "",
        "created": "",
        "modified": "",
        "language": "",
        "ethical_issues_exist": "",
        "ethical_issues_description": "",
        "ethical_issues_report": "",

        "contact": {
            "name": "",
            "mbox": "",
            "contact_id": {
                "identifier": "",
                "type": ""
            },
            "affiliation": [
                {
                    "name": "",
                    "affiliation_id": {
                        "identifier": "",
                        "type": ""
                    }
                }
            ]
        },

        "contributor": [
            {
                "name": "",
                "mbox": "",
                "role": [],
                "contributor_id": {
                    "identifier": "",
                    "type": ""
                },
                "affiliation": [
                    {
                        "name": "",
                        "affiliation_id": {
                            "identifier": "",
                            "type": ""
                        }
                    }
                ]
            }
        ],

        "cost": [
            {
                "title": "",
                "description": "",
                "value": None,
                "currency_code": ""
            }
        ],

        "project": [
            {
                "title": "",
                "description": "",
                "start": "",
                "end": "",
                "project_id": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],
                "funding": [
                    {
                        "funder_name": "",
                        "funder_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "grant_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "funding_status": ""
                    }
                ]
            }
        ],

        "dataset": [
            {
                "dataset_id": {
                    "identifier": "",
                    "type": ""
                },
                "title": "",
                "description": "",
                "type": "",
                "issued": "",
                "language": "",
                "keyword": [],
                "is_reused": None,
                "personal_data": "",
                "sensitive_data": "",
                "preservation_statement": "",
                "data_quality_assurance": [],
                "security_and_privacy": [
                    {
                        "title": "",
                        "description": ""
                    }
                ],
                "rights": "",

                "alternate_identifier": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],

                "creator": [
                    {
                        "name": "",
                        "mbox": "",
                        "creator_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "affiliation": [
                            {
                                "name": "",
                                "affiliation_id": {
                                    "identifier": "",
                                    "type": ""
                                }
                            }
                        ]
                    }
                ],

                "distribution": [
                    {
                        "title": "",
                        "description": "",
                        "access_url": "",
                        "available_until": "",
                        "byte_size": None,
                        "data_access": "",
                        "download_url": "",
                        "format": [],
                        "issued": "",
                        "license": [
                            {
                                "license_ref": "",
                                "start_date": ""
                            }
                        ],
                        "host": {
                            "title": "",
                            "url": "",
                            "description": "",
                            "availability": "",
                            "backup_frequency": "",
                            "backup_type": "",
                            "certified_with": "",
                            "geo_location": "",
                            "host_id": {
                                "identifier": "",
                                "type": ""
                            },
                            "pid_system": [],
                            "storage_type": "",
                            "support_versioning": ""
                        }
                    }
                ],

                "metadata": [
                    {
                        "description": "",
                        "language": "",
                        "metadata_standard_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ],

                "related_identifier": [
                    {
                        "identifier": "",
                        "type": "",
                        "relation_type": "",
                        "metadata_scheme": "",
                        "scheme_uri": "",
                        "scheme_type": "",
                        "resource_type": ""
                    }
                ],

                "technical_resource": [
                    {
                        "name": "",
                        "description": "",
                        "technical_resource_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ]
            }
        ],

        "alternate_identifier": [
            {
                "identifier": "",
                "type": ""
            }
        ],

        "related_identifier": [
            {
                "identifier": "",
                "type": "",
                "relation_type": "",
                "metadata_scheme": "",
                "scheme_uri": "",
                "scheme_type": "",
                "resource_type": ""
            }
        ]
    }
}
# save the schema skeleton to a JSON file
with open("RDA_DMP_schema_skeleton.json", "w", encoding="utf-8") as f:
    json.dump(RDA_DMP_schema_skeleton, f, indent=2, ensure_ascii=False)

print("Saved: RDA_DMP_schema_skeleton.json")
# Out:
# Saved: RDA_DMP_schema_skeleton.json

# %% [markdown]
# # 2. DMPtools Common Standard for machine-actionable Data Management Plans

# %%
# .JSON-style DMPTool schema skeleton
import json

dmptool_schema_skeleton = {
    "title": "",
    "created": "",
    "modified": "",
    "ethical_issues_exist": "",
    "language": "",

    "dmp_id": {
        "identifier": "",
        "type": ""
    },

    "contact": {
        "name": "",
        "mbox": "",
        "contact_id": {
            "identifier": "",
            "type": ""
        },
        "affiliation": {
            "name": "",
            "affiliation_id": {
                "identifier": "",
                "type": ""
            }
        }
    },

    "dataset": [
        {
            "title": "",
            "type": "",
            "personal_data": "",
            "sensitive_data": "",
            "dataset_id": {
                "identifier": "",
                "type": ""
            }
        }
    ],

    "project": [
        {
            "title": "",
            "description": "",
            "funding_status": "",
            "funding": [
                {
                    "name": "",
                    "funder_id": {
                        "identifier": "",
                        "type": ""
                    }
                }
            ]
        }
    ],

    "provenance": "dmpbridge",

    "narrative": {
        "title": "",
        "section": [
            {
                "order": None,
                "title": "",
                "description": "",
                "question": [
                    {
                        "order": None,
                        "text": "",
                        "answer": {
                            "json": {
                                "answer": "",
                                "type": ""
                            }
                        }
                    }
                ]
            }
        ]
    }
}

with open("dmptool_schema_skeleton.json", "w", encoding="utf-8") as f:
    json.dump(dmptool_schema_skeleton, f, indent=2, ensure_ascii=False)

print("Saved: dmptool_schema_skeleton.json")
print("Final corrected DMPTool schema skeleton defined.")
# Out:
# Saved: dmptool_schema_skeleton.json
# Final corrected DMPTool schema skeleton defined.

# %% [markdown]
# # 3. DMPTool-Specific Narrative Layer

# %%
import json

dmptool_narrative_skeleton = {
    "provenance": "dmpbridge",
    "narrative": {
        "title": "",
        "section": [
            {
                "order": None,
                "title": "",
                "description": "",
                "question": [
                    {
                        "order": None,
                        "text": "",
                        "answer": {
                            "json": {
                                "answer": "",
                                "type": ""
                            }
                        }
                    }
                ]
            }
        ]
    }
}


with open("dmptool_narrative_skeleton.json", "w", encoding="utf-8") as f:
    json.dump(dmptool_narrative_skeleton, f, indent=2, ensure_ascii=False)

print("Saved: dmptool_narrative_skeleton.json")
# Out:
# Saved: dmptool_narrative_skeleton.json
