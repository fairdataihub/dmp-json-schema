# %% [markdown]
# # 1. JSON-style schema skeleton

# %%
#Import libraries
import requests
import xml.etree.ElementTree as ET
import json
from jsonschema import validate

# %%
# Final corrected maDMP schema skeleton
DMP_schema_skeleton = {
    "$schema": "./JSON-schema/1.2/maDMP-schema-1.2.json",
    "dmp": {
        "dmp_id": {
            "identifier": "",
            "type": ""
        },
        "title": "",
        "description": "",
        "created": "",
        "modified": "",
        "language": "",
        "ethical_issues_exist": "",
        "ethical_issues_description": "",
        "ethical_issues_report": "",

        "contact": {
            "name": "",
            "mbox": "",
            "contact_id": {
                "identifier": "",
                "type": ""
            },
            "affiliation": [
                {
                    "name": "",
                    "affiliation_id": {
                        "identifier": "",
                        "type": ""
                    }
                }
            ]
        },

        "contributor": [
            {
                "name": "",
                "mbox": "",
                "role": [],
                "contributor_id": {
                    "identifier": "",
                    "type": ""
                },
                "affiliation": [
                    {
                        "name": "",
                        "affiliation_id": {
                            "identifier": "",
                            "type": ""
                        }
                    }
                ]
            }
        ],

        "cost": [
            {
                "title": "",
                "description": "",
                "value": 0,
                "currency_code": ""
            }
        ],

        "project": [
            {
                "title": "",
                "description": "",
                "start": "",
                "end": "",
                "project_id": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],
                "funding": [
                    {
                        "funder_name": "",
                        "funder_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "grant_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "funding_status": ""
                    }
                ]
            }
        ],

        "dataset": [
            {
                "dataset_id": {
                    "identifier": "",
                    "type": ""
                },
                "title": "",
                "description": "",
                "type": "",
                "issued": "",
                "language": "",
                "keyword": [],
                "is_reused": False,
                "personal_data": "",
                "sensitive_data": "",
                "preservation_statement": "",
                "data_quality_assurance": [],
                "security_and_privacy": [
                    {
                        "title": "",
                        "description": ""
                    }
                ],
                "rights": "",

                "alternate_identifier": [
                    {
                        "identifier": "",
                        "type": ""
                    }
                ],

                "creator": [
                    {
                        "name": "",
                        "mbox": "",
                        "creator_id": {
                            "identifier": "",
                            "type": ""
                        },
                        "affiliation": [
                            {
                                "name": "",
                                "affiliation_id": {
                                    "identifier": "",
                                    "type": ""
                                }
                            }
                        ]
                    }
                ],

                "distribution": [
                    {
                        "title": "",
                        "description": "",
                        "access_url": "",
                        "available_until": "",
                        "byte_size": 0,
                        "data_access": "",
                        "download_url": "",
                        "format": [],
                        "issued": "",
                        "license": [
                            {
                                "license_ref": "",
                                "start_date": ""
                            }
                        ],
                        "host": {
                            "title": "",
                            "url": "",
                            "description": "",
                            "availability": "",
                            "backup_frequency": "",
                            "backup_type": "",
                            "certified_with": "",
                            "geo_location": "",
                            "host_id": {
                                "identifier": "",
                                "type": ""
                            },
                            "pid_system": [],
                            "storage_type": "",
                            "support_versioning": ""
                        }
                    }
                ],

                "metadata": [
                    {
                        "description": "",
                        "language": "",
                        "metadata_standard_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ],

                "related_identifier": [
                    {
                        "identifier": "",
                        "type": "",
                        "relation_type": "",
                        "metadata_scheme": "",
                        "scheme_uri": "",
                        "scheme_type": "",
                        "resource_type": ""
                    }
                ],

                "technical_resource": [
                    {
                        "name": "",
                        "description": "",
                        "technical_resource_id": [
                            {
                                "identifier": "",
                                "type": ""
                            }
                        ]
                    }
                ]
            }
        ],

        "alternate_identifier": [
            {
                "identifier": "",
                "type": ""
            }
        ],

        "related_identifier": [
            {
                "identifier": "",
                "type": "",
                "relation_type": "",
                "metadata_scheme": "",
                "scheme_uri": "",
                "scheme_type": "",
                "resource_type": ""
            }
        ],
        "provenance": "",

        "narrative": {
            "title": "",
            "section": [
                {
                    "order": "",
                    "title": "",
                    "description": "",
                    "question": [
                        {
                            "order": "",
                            "text": "",
                            "answer": {
                                "json": {
                                    "answer": "",
                                    "type": ""
                                }
                            }
                        }
                    ]
                }
            ]
        }
    }
}


print("Final corrected schema defined.")
# Out:
# Final corrected schema defined.

# %%
# Step 2 — save the schema
with open("DMP_schema_skeleton.json", "w", encoding="utf-8") as f:
    json.dump(DMP_schema_skeleton, f, indent=2, ensure_ascii=False)

print("Saved: DMP_schema_skeleton.json")
# Out:
# Saved: DMP_schema_skeleton.json
